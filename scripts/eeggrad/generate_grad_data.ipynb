# %%
# !python generate_grad_data.py --device 1
# Out:
# 2024-02-13_H1_CL_2 CL_H1 0
# extended enabled
# EEGNet with output dim 4
# 2024-02-13_H1_CL_3 CL_H1 0
# extended enabled
# EEGNet with output dim 4
# 2024-02-14_H1_CL_1 CL_H1 0
# extended enabled
# EEGNet with output dim 4
# 2024-02-14_H1_CL_2 CL_H1 0
# extended enabled
# EEGNet with output dim 4
# 2024-02-14_H1_CL_3 CL_H1 0
# extended enabled
# EEGNet with output dim 4
# 2024-02-14_H1_CL_4 CL_H1 0
# extended enabled
# EEGNet with output dim 4
# 2024-02-15_H1_CL_1 CL_H1 0
# extended enabled
# EEGNet with output dim 4
# 2024-02-15_H1_CL_2 CL_H1 0
# extended enabled
# EEGNet with output dim 4
# 2024-02-15_H1_CL_3 CL_H1 0
# extended enabled
# EEGNet with output dim 4
# 2024-02-15_H1_CL_4 CL_H1 0
# extended enabled
# EEGNet with output dim 4
# 2024-02-20_H1_CL_1 CL_H1 0
# extended enabled
# EEGNet with output dim 4
# 2024-02-20_H1_CL_2 CL_H1 0
# extended enabled
# EEGNet with output dim 4
# 2024-02-20_H1_CL_3 CL_H1 0
# extended enabled
# EEGNet with output dim 4
# ...

# %%
# !python generate_grad_data.py --device 1
# Out:
# 2024-03-18_S2_CL_1 CL_S2_2024-02-27 4
# extended enabled
# EEGNet with output dim 4
# 2024-03-18_S2_CL_2 CL_S2_2024-02-27 4
# extended enabled
# EEGNet with output dim 4
